# %% [markdown]
# <a href="https://colab.research.google.com/github/Megh-ops/Rule-Based-Sentiment-Analysis/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

x; = pd.read_excel (r'/Comments - PFA S2.xlsx')
print (df)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Comments - PFA S2.xlsx")
df
# Out:
#                     Name  ... Reply Count
# 0             Dice Media  ...         347
# 1     A-10 Sneha Gaikwad  ...           0
# 2          Priyank Khare  ...           0
# 3           Manish Kumar  ...           0
# 4           Manish Kumar  ...           0
# ...                  ...  ...         ...
# 5662            eyeconic  ...           1
# 5663               rehan  ...           0
# 5664    Amit Srivasatava  ...           3
# 5665        nitish rawat  ...           0
# 5666    Amit Srivasatava  ...           1
#
# [5667 rows x 5 columns]

# %% [markdown]
# ### Emoji & Emoticon handling

# %%
# !pip install emot
# Out:
# ...
#      |████████████████████████████████| 61 kB 14 kB/s
# ...

# %%
df.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))
# Out:
#                     Name  ... Reply Count
# 0             Dice Media  ...         347
# 1     A-10 Sneha Gaikwad  ...           0
# 2          Priyank Khare  ...           0
# 3           Manish Kumar  ...           0
# 4           Manish Kumar  ...           0
# ...                  ...  ...         ...
# 5662            eyeconic  ...           1
# 5663               rehan  ...           0
# 5664    Amit Srivasatava  ...           3
# 5665        nitish rawat  ...           0
# 5666    Amit Srivasatava  ...           1
#
# [5667 rows x 5 columns]

# %% [markdown]
# ### Preprocessing

# %%
df=df.drop(['Name','Time'], axis=1)
df.head(5)
# Out:
#                                              Comment  Likes  Reply Count
# 0  How did you guys like the episode? ❤️ Tell us ...   3865          347
# 1                                           Venkat 😂      0            0
# 2                            This show is aging well      0            0
# 3  .<br><br><br><br><br><br><br><br><br><br><br><...      0            0
# 4                                                  .      0            0

# %%
def clean(text):

    text = re.sub('[^A-Za-z]+', ' ', text)
    return text

df['Cleaned Comments'] = df['Comment'].astype(str).apply(clean)

# %%
df.head()
# Out:
#                                              Comment  ...                                   Cleaned Comments
# 0  How did you guys like the episode? ❤️ Tell us ...  ...  How did you guys like the episode Tell us in c...
# 1                                           Venkat 😂  ...                                            Venkat
# 2                            This show is aging well  ...                            This show is aging well
# 3  .<br><br><br><br><br><br><br><br><br><br><br><...  ...   br br br br br br br br br br br br br br br ...
# 4                                                  .  ...
#
# [5 rows x 4 columns]

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk import pos_tag
nltk.download('stopwords')
from nltk.corpus import stopwords
nltk.download('wordnet')
from nltk.corpus import wordnet
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
pos_dict = {'J':wordnet.ADJ, 'V':wordnet.VERB, 'N':wordnet.NOUN, 'R':wordnet.ADV}
def token_stop_pos(text):
    tags = pos_tag(word_tokenize(text))
    newlist = []
    for word, tag in tags:
        if word.lower() not in set(stopwords.words('english')):
          newlist.append(tuple([word, pos_dict.get(tag[0])]))

        
    return newlist

df['POS tagged'] = df['Cleaned Comments'].apply(token_stop_pos)

# %%
df.head()
# Out:
#                                              Comment  ...                                         POS tagged
# 0  How did you guys like the episode? ❤️ Tell us ...  ...  [(guys, v), (like, None), (episode, n), (Tell,...
# 1                                           Venkat 😂  ...                                      [(Venkat, n)]
# 2                            This show is aging well  ...                 [(show, n), (aging, v), (well, r)]
# 3  .<br><br><br><br><br><br><br><br><br><br><br><...  ...  [(br, n), (br, n), (br, n), (br, n), (br, n), ...
# 4                                                  .  ...                                                 []
#
# [5 rows x 5 columns]

# %%
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
def lemmatize(pos_data):
    lemma_rew = " "
    for word, pos in pos_data:
    if not pos:
        lemma = word
        lemma_rew = lemma_rew + " " + lemma
    else:
        lemma = wordnet_lemmatizer.lemmatize(word, pos=pos)
        lemma_rew = lemma_rew + " " + lemma
    return lemma_rew

df['Lemma'] = df['POS tagged'].apply(lemmatize)
mydata.head()
